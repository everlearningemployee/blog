# %%
#hide
import matplotlib.pyplot as plt
from matplotlib import font_manager
plt.rcParams["font.family"] = 'gulim'
plt.rcParams["figure.figsize"] = (15,5)

import pandas as pd

# %% [markdown]
# ## COVID-19
# - https://github.com/CSSEGISandData/COVID-19
#  - [국가별 확진자 csv](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv)

# %%
csv_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(csv_url).set_index(['Province/State', 'Country/Region'])

# %%
df
# Out:
#                                          Lat       Long  1/22/20  1/23/20  \
# Province/State Country/Region
# NaN            Afghanistan         33.939110  67.709953        0        0
#                Albania             41.153300  20.168300        0        0
#                Algeria             28.033900   1.659600        0        0
#                Andorra             42.506300   1.521800        0        0
#                Angola             -11.202700  17.873900        0        0
# ...                                      ...        ...      ...      ...
#                West Bank and Gaza  31.952200  35.233200        0        0
#                Western Sahara      24.215500 -12.885800        0        0
#                Yemen               15.552727  48.516388        0        0
#                Zambia             -13.133897  27.849332        0        0
#                Zimbabwe           -19.015438  29.154857        0        0
#
# ...

# %%
df.loc[('New South Wales', 'Australia')]
# Out:
# Lat         -33.8688
# Long        151.2093
# 1/22/20       0.0000
# 1/23/20       0.0000
# 1/24/20       0.0000
#              ...
# 8/18/20    3966.0000
# 8/19/20    3971.0000
# 8/20/20    3972.0000
# 8/21/20    3981.0000
# 8/22/20    3985.0000
# Name: (New South Wales, Australia), Length: 216, dtype: float64

# %%
df.loc[(None, 'Korea, South')]
# Out:
# Lat           35.907757
# Long         127.766922
# 1/22/20        1.000000
# 1/23/20        1.000000
# 1/24/20        2.000000
#                ...
# 8/18/20    16058.000000
# 8/19/20    16346.000000
# 8/20/20    16670.000000
# 8/21/20    17002.000000
# 8/22/20    17399.000000
# Name: (nan, Korea, South), Length: 216, dtype: float64

# %%
df[df.index.get_level_values('Country/Region') == 'Australia']
# Out:
#                                                  Lat      Long  1/22/20  \
# Province/State               Country/Region
# Australian Capital Territory Australia      -35.4735  149.0124        0
# New South Wales              Australia      -33.8688  151.2093        0
# Northern Territory           Australia      -12.4634  130.8456        0
# Queensland                   Australia      -27.4698  153.0251        0
# South Australia              Australia      -34.9285  138.6007        0
# Tasmania                     Australia      -42.8821  147.3272        0
# Victoria                     Australia      -37.8136  144.9631        0
# Western Australia            Australia      -31.9505  115.8605        0
#
#                                              1/23/20  1/24/20  1/25/20  \
# Province/State               Country/Region
# Australian Capital Territory Australia             0        0        0
# New South Wales              Australia             0        0        0
# ...

# %%
kr = df[df.index.get_level_values('Country/Region') == 'Korea, South']

# %%
cntr_df = df.groupby(['Country/Region']).sum()
cntr_df
# Out:
#                           Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan         33.939110  67.709953        0        0        0        0
# Albania             41.153300  20.168300        0        0        0        0
# Algeria             28.033900   1.659600        0        0        0        0
# Andorra             42.506300   1.521800        0        0        0        0
# Angola             -11.202700  17.873900        0        0        0        0
# ...                       ...        ...      ...      ...      ...      ...
# West Bank and Gaza  31.952200  35.233200        0        0        0        0
# Western Sahara      24.215500 -12.885800        0        0        0        0
# Yemen               15.552727  48.516388        0        0        0        0
# Zambia             -13.133897  27.849332        0        0        0        0
# Zimbabwe           -19.015438  29.154857        0        0        0        0
#
# ...

# %%
cntr_df[cntr_df.index == 'Australia'].T
# Out:
# Country/Region   Australia
# Lat              -256.8502
# Long             1130.8439
# 1/22/20             0.0000
# 1/23/20             0.0000
# 1/24/20             0.0000
# ...                    ...
# 8/18/20         23989.0000
# 8/19/20         24236.0000
# 8/20/20         24407.0000
# 8/21/20         24602.0000
# 8/22/20         24811.0000
#
# [216 rows x 1 columns]

# %%
cntr_df.loc['Australia']
# Out:
# Lat         -256.8502
# Long        1130.8439
# 1/22/20        0.0000
# 1/23/20        0.0000
# 1/24/20        0.0000
#               ...
# 8/18/20    23989.0000
# 8/19/20    24236.0000
# 8/20/20    24407.0000
# 8/21/20    24602.0000
# 8/22/20    24811.0000
# Name: Australia, Length: 216, dtype: float64
